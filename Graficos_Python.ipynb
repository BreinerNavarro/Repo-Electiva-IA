# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-5, 5, 100)
y = x**2

plt,plt.plot(x,y)
# Out:
# (<module 'matplotlib.pyplot' from 'c:\\Users\\soporte.sistemas\\OneDrive - Fundación Universitaria Cafam\\Documentos\\MATERIAS\\ELECTIVA_I_HERRAMIENTAS_IA\\Repo-Electiva-IA\\.venv\\Lib\\site-packages\\matplotlib\\pyplot.py'>,
#  [<matplotlib.lines.Line2D at 0x1a7eed26cf0>])
